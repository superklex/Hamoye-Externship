# %% [markdown]
# <a href="https://colab.research.google.com/github/superklex/Hamoye-externship/blob/master/Quiz_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sklearn
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/superklex/my_datasets/master/energydata.csv")
df.head()
# Out:
#                   date  Appliances  lights  ...  Tdewpoint        rv1        rv2
# 0  2016-01-11 17:00:00          60      30  ...        5.3  13.275433  13.275433
# 1  2016-01-11 17:10:00          60      30  ...        5.2  18.606195  18.606195
# 2  2016-01-11 17:20:00          50      30  ...        5.1  28.642668  28.642668
# 3  2016-01-11 17:30:00          50      40  ...        5.0  45.410389  45.410389
# 4  2016-01-11 17:40:00          60      40  ...        4.9  10.084097  10.084097
#
# [5 rows x 29 columns]

# %%
df.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
df.shape
# Out:
# (19735, 29)

# %%
df.corr()
# Out:
#              Appliances    lights        T1  ...  Tdewpoint       rv1       rv2
# Appliances     1.000000  0.197278  0.055447  ...   0.015353 -0.011145 -0.011145
# lights         0.197278  1.000000 -0.023528  ...  -0.036322  0.000521  0.000521
# T1             0.055447 -0.023528  1.000000  ...   0.571309 -0.006203 -0.006203
# RH_1           0.086031  0.106968  0.164006  ...   0.639106 -0.000699 -0.000699
# T2             0.120073 -0.005622  0.836834  ...   0.582602 -0.011087 -0.011087
# RH_2          -0.060465  0.050985 -0.002509  ...   0.499152  0.006275  0.006275
# T3             0.085060 -0.097393  0.892402  ...   0.645886 -0.005194 -0.005194
# RH_3           0.036292  0.131161 -0.028550  ...   0.414387 -0.000477 -0.000477
# T4             0.040281 -0.008859  0.877001  ...   0.519471 -0.001815 -0.001815
# RH_4           0.016965  0.114936  0.097861  ...   0.616509 -0.001787 -0.001787
# T5             0.019760 -0.078745  0.885247  ...   0.588362 -0.005490 -0.005490
# ...

# %%
df.describe()
# Out:
#          Appliances        lights  ...           rv1           rv2
# count  19735.000000  19735.000000  ...  19735.000000  19735.000000
# mean      97.694958      3.801875  ...     24.988033     24.988033
# std      102.524891      7.935988  ...     14.496634     14.496634
# min       10.000000      0.000000  ...      0.005322      0.005322
# 25%       50.000000      0.000000  ...     12.497889     12.497889
# 50%       60.000000      0.000000  ...     24.897653     24.897653
# 75%      100.000000      0.000000  ...     37.583769     37.583769
# max     1080.000000     70.000000  ...     49.996530     49.996530
#
# [8 rows x 28 columns]

# %%
df1= df.drop(df.columns.difference(["T2", "T6"]), axis = 1)
df1
# Out:
#               T2         T6
# 0      19.200000   7.026667
# 1      19.200000   6.833333
# 2      19.200000   6.560000
# 3      19.200000   6.433333
# 4      19.200000   6.366667
# ...          ...        ...
# 19730  25.890000  24.796667
# 19731  25.754000  24.196667
# 19732  25.628571  23.626667
# 19733  25.414000  22.433333
# 19734  25.264286  21.026667
#
# [19735 rows x 2 columns]

# %%
#normalizing using the minmaxscaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df1 = pd.DataFrame(scaler.fit_transform(df1), columns=df1.columns)
x = df1.T2.to_numpy()
y = df1.T6.to_numpy()

# %%
#reshaping to change the array dimension
x=x.reshape(-1, 1)
y=y.reshape(-1, 1)

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
lin_model = linear_model.LinearRegression()
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
#fit the model to the training dataset
lin_model.fit(x_train, y_train)
#obtain predictions
predicted = lin_model.predict(x_test)
print(predicted)
# Out:
# [[0.23928945]
#  [0.46794238]
#  [0.23108472]
#  ...
#  [0.3001772 ]
#  [0.4297256 ]
#  [0.3217686 ]]

# %%
#12 R squared value in 2dp
from sklearn.metrics import r2_score
r2 = r2_score(y_test, predicted).round(2)
r2
# Out:
# 0.64

# %%
fig, ax = plt.subplots()
ax.scatter(y_test, predicted)
ax.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw = 4)
ax.set_xlabel('Actual')
ax.set_ylabel('Predicted')
ax.plot(y_test, lin_model.fit(y_test, predicted).predict(y_test))
ax.set_title("R2: " + str(r2))
# Out:
# Text(0.5, 1.0, 'R2: 0.64')

# %%
#13 Mean Absolute error in 2dp
from sklearn.metrics import mean_absolute_error as mae
mae = mae(y_test, predicted).round(2)
mae
# Out:
# 0.08

# %%
#14 Residual sum of squares in 2dp
rss= np.sum(np.square(y_test - predicted)).round(2)
rss
# Out:
# 66.12

# %%
#15 Root mean squared error in 3 dp
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, predicted)).round(3)
rmse
# Out:
# 0.106

# %%
#16 Coefficient of  determination
from sklearn.metrics import r2_score
COD = r2_score(y_test, predicted).round(2)
COD
# Out:
# 0.64

# %%
df2 = df.drop(["date","lights"], axis =1)
df2 = pd.DataFrame(scaler.fit_transform(df2), columns=df2.columns)
X = df2.drop("Appliances", axis =1)
Y = df2["Appliances"]
#.to_numpy()

# %%
line_model = linear_model.LinearRegression()
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
#fit the model to the training dataset
line_model.fit(X_train, Y_train)
#obtain predictions
pred = line_model.predict(X_test)
print(pred)
# Out:
# [0.03322207 0.24411599 0.03400024 ... 0.06844707 0.10032325 0.05722198]

# %%
def get_weights_df(model, feat, col_name):
  weights = pd.Series(model.coef_, feat.columns).sort_values()
  #weights = pd.DataFrame(data=df2, columns=['Features'])
  weights_df = pd.DataFrame(weights). reset_index()
  weights_df.columns = ["Features", col_name]
  weights_df[col_name].round(3)
  return weights_df
linear_model_weights = get_weights_df(line_model, X_train, "Linear_Model_Weight")
linear_model_weights
# Out:
#        Features  Linear_Model_Weight
# 0          RH_2            -0.456698
# 1         T_out            -0.321860
# 2            T2            -0.236178
# 3            T9            -0.189941
# 4          RH_8            -0.157595
# 5        RH_out            -0.077671
# 6          RH_7            -0.044614
# 7          RH_9            -0.039800
# 8            T5            -0.015657
# 9            T1            -0.003281
# 10          rv1             0.000770
# 11          rv2             0.000770
# 12  Press_mm_hg             0.006839
# 13           T7             0.010319
# 14   Visibility             0.012307
# 15         RH_5             0.016006
# 16         RH_4             0.026386
# 17           T4             0.028981
# 18    Windspeed             0.029183
# 19         RH_6             0.038049
# 20         RH_3             0.096048
# 21           T8             0.101995
# 22    Tdewpoint             0.117758
# 23           T6             0.236425
# ...

# %%
#Question 17
print("RH_1 and RH_2")
# Out:
# RH_1 and RH_2

# %%
from sklearn.linear_model import Ridge

# %%
ridge = Ridge(alpha = 0.4)
ridge.fit(X_train, Y_train)
R_predict1= ridge.predict(X_train)
rmse1 = np.sqrt(mean_squared_error(Y_train, R_predict1)).round(2)
rmse1
# Out:
# 0.09

# %%
ridge.fit(X_test, Y_test)
R_predict2= ridge.predict(X_test)
rmse2 = np.sqrt(mean_squared_error(Y_test, R_predict2)).round(2)
rmse2
# Out:
# 0.09

# %%
#Question 18
print("There is no change")
# Out:
# There is no change

# %%
#Question 19
from sklearn.linear_model import Lasso

# %%
lasso = Lasso(alpha = 0.001)
lasso.fit(X_train, Y_train)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
lasso_weights_df = get_weights_df(lasso, X_train, "Lasso_weight")
lasso_weights_df
# Out:
#        Features  Lasso_weight
# 0        RH_out     -0.049557
# 1          RH_8     -0.000110
# 2            T1      0.000000
# 3     Tdewpoint      0.000000
# 4    Visibility      0.000000
# 5   Press_mm_hg     -0.000000
# 6         T_out      0.000000
# 7          RH_9     -0.000000
# 8            T9     -0.000000
# 9            T8      0.000000
# 10         RH_7     -0.000000
# 11          rv1     -0.000000
# 12           T7     -0.000000
# 13           T6      0.000000
# 14         RH_5      0.000000
# 15           T5     -0.000000
# 16         RH_4      0.000000
# 17           T4     -0.000000
# 18         RH_3      0.000000
# 19           T3      0.000000
# 20         RH_2     -0.000000
# 21           T2      0.000000
# 22         RH_6     -0.000000
# 23          rv2     -0.000000
# 24    Windspeed      0.002912
# 25         RH_1      0.017880

# %%
lasso_weights_df[lasso_weights_df['Lasso_weight'] != 0].count()
# Out:
# Features        4
# Lasso_weight    4
# dtype: int64

# %%
# four features have non zero weight

# %%
#Question 20
lasso_pred = lasso.predict(X_test)
lasso_rmse = np.sqrt(mean_squared_error(Y_test, lasso_pred)).round(3)
lasso_rmse
# Out:
# 0.094

# %%
print("RMSE is unchanged")
# Out:
# RMSE is unchanged
